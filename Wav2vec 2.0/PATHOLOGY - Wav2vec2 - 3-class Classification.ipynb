# %%
# !nvidia-smi
# Out:
# Sun Nov  7 23:29:34 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    31W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip -q install torchaudio
# !pip -q install datasets

import pandas as pd
import numpy as np
import os
from tqdm import tqdm_notebook as tqdm
from shutil import copyfile

import librosa
import librosa.display
import scipy.io.wavfile as wav

import IPython.display as ipd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
#      |████████████████████████████████| 2.9 MB 10.9 MB/s
#      |██████████████████████████████▎ | 834.1 MB 1.3 MB/s eta 0:00:36tcmalloc: large alloc 1147494400 bytes == 0x55c377b30000 @  0x7f9c29ce3615 0x55c33ef134cc 0x55c33eff347a 0x55c33ef162ed 0x55c33f007e1d 0x55c33ef89e99 0x55c33ef849ee 0x55c33ef17bda 0x55c33ef89d00 0x55c33ef849ee 0x55c33ef17bda 0x55c33ef86737 0x55c33f008c66 0x55c33ef85daf 0x55c33f008c66 0x55c33ef85daf 0x55c33f008c66 0x55c33ef85daf 0x55c33ef18039 0x55c33ef5b409 0x55c33ef16c52 0x55c33ef89c25 0x55c33ef849ee 0x55c33ef17bda 0x55c33ef86737 0x55c33ef849ee 0x55c33ef17bda 0x55c33ef85915 0x55c33ef17afa 0x55c33ef85c0d 0x55c33ef849ee
#      |████████████████████████████████| 881.9 MB 19 kB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.10.0+cu111 requires torch==1.9.0, but you have torch 1.10.0 which is incompatible.
# torchtext 0.10.0 requires torch==1.9.0, but you have torch 1.10.0 which is incompatible.

# %%
import pandas as pd
from torch.utils.data import Dataset

import torch

# %%
!7z x /content/drive/MyDrive/Tesi/dataset_pat_bandPass2.zip -o/content/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.30GHz (306F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 file, 598041763 bytes (571 MiB)
#
# Extracting archive: /content/drive/MyDrive/Tesi/dataset_pat_bandPass2.zip
# --
# Path = /content/drive/MyDrive/Tesi/dataset_pat_bandPass2.zip
# Type = zip
# Physical Size = 598041763
#
# Everything is Ok
#
# Folders: 1
# Files: 920
# Size:       872031202
# Compressed: 598041763

# %%
train_pathology = pd.read_csv('/content/drive/MyDrive/Tesi/train_multiclass_pathology.csv')
test_pathology = pd.read_csv('/content/drive/MyDrive/Tesi/test_multiclass_pathology.csv')

# %%
train_multiclass = train_pathology.copy()
train_multiclass
# Out:
#                                               filename  label
# 0    /content/dataset_pat_bandPass2/205_1b3_Ar_mc_A...      1
# 1    /content/dataset_pat_bandPass2/151_3p2_Al_mc_A...      1
# 2    /content/dataset_pat_bandPass2/226_1b1_Ll_sc_M...      2
# 3    /content/dataset_pat_bandPass2/130_3p2_Pl_mc_A...      1
# 4    /content/dataset_pat_bandPass2/135_2b2_Al_mc_L...      2
# ..                                                 ...    ...
# 731  /content/dataset_pat_bandPass2/186_3b3_Tc_mc_A...      1
# 732  /content/dataset_pat_bandPass2/112_1p1_Pl_sc_L...      1
# 733  /content/dataset_pat_bandPass2/138_1p3_Pl_mc_A...      1
# 734  /content/dataset_pat_bandPass2/197_1b1_Al_sc_M...      2
# 735  /content/dataset_pat_bandPass2/159_1b1_Al_sc_M...      0
#
# [736 rows x 2 columns]

# %%
test_multiclass = test_pathology.copy()
test_multiclass
# Out:
#                                               filename  label
# 0    /content/dataset_pat_bandPass2/199_2b3_Ll_mc_L...      1
# 1    /content/dataset_pat_bandPass2/181_1b3_Tc_mc_L...      1
# 2    /content/dataset_pat_bandPass2/195_1b1_Al_sc_L...      1
# 3    /content/dataset_pat_bandPass2/160_1b3_Tc_mc_A...      1
# 4    /content/dataset_pat_bandPass2/211_1p2_Ar_mc_A...      1
# ..                                                 ...    ...
# 179  /content/dataset_pat_bandPass2/139_1b1_Ll_sc_L...      1
# 180  /content/dataset_pat_bandPass2/186_3b3_Pl_mc_A...      1
# 181  /content/dataset_pat_bandPass2/163_2b2_Lr_mc_A...      1
# 182  /content/dataset_pat_bandPass2/217_1b1_Tc_sc_M...      0
# 183  /content/dataset_pat_bandPass2/134_2b2_Ar_mc_L...      1
#
# [184 rows x 2 columns]

# %%
train_multiclass.groupby('label').count()
# Out:
#        filename
# label
# 0            25
# 1           648
# 2            63

# %%
test_multiclass.groupby('label').count()
# Out:
#        filename
# label
# 0            10
# 1           162
# 2            12

# %%
# !pip -q install torchaudio
# !pip -q install transformers
# Out:
#      |████████████████████████████████| 3.1 MB 13.2 MB/s
#      |████████████████████████████████| 596 kB 45.3 MB/s
#      |████████████████████████████████| 3.3 MB 33.2 MB/s
#      |████████████████████████████████| 895 kB 40.6 MB/s
#      |████████████████████████████████| 59 kB 5.4 MB/s

# %%
import torchaudio
duration = 20
freq = 16
class AudiosDataset(Dataset):
    def __init__(self, paths=None, targets=None, augment=False) -> None:
        self.paths = paths
        self.targets = targets
        self.augment = augment
        
    
    def __len__(self) -> int:
        return len(self.paths)

    def __getitem__(self, idx: int) -> dict:
        y, sr = torchaudio.load(self.paths.iloc[idx])#, normalization=True)
        """
        if self.augment:
            effects = [
                    ["lowpass", "-1", "300"], 
                    ["speed", f"{random.uniform(0.7, 1.3)}"],  # change speed
                  ]
            y, sr = torchaudio.sox_effects.apply_effects_tensor(
                y, sr, effects)
        #
            
        if self.augment:
            # augment sound in order to imitate the room change
            rir = self.rir[:, int(16000*1.1):int(16000*1.3)]
            rir = rir / torch.norm(rir, p=2)
            rir = torch.flip(rir, [1])
            y = torch.nn.functional.conv1d(y[None, ...], rir[None, ...])[0]
        
        """
        # here more augmentations could be used
        y = torchaudio.transforms.Resample(orig_freq=sr, new_freq=freq*1000)(y)

        """
        if self.augment:
            y = (0.5)*torch.randn(y.shape)
        """
        fixed_length = (freq*1000) * duration
        
        # returning result
        if y.shape[1] < fixed_length:
            y = torch.nn.functional.pad(
              y, (0, fixed_length - y.shape[1]))
        else:
            y = y[:, :fixed_length]
        result = {"target":self.targets.iloc[idx], "representation":y}
        return result

# %%
train_ds = AudiosDataset(train_multiclass['filename'], train_multiclass['label'])
test_ds = AudiosDataset(test_multiclass['filename'], test_multiclass['label'])

# %%
from torch.utils.data import TensorDataset, DataLoader

batch_size = 8
num_workers = 10
loaders = {
    "train": DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        drop_last=True,
    ),
    "test": DataLoader(
        test_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        drop_last=True,
    )
}
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
from torch import nn
import torch.nn.functional as F

class ClassificationHead(nn.Module):
    """Head for wav2vec2 classification task."""

    def __init__(self):
        super().__init__()
        self.dense = nn.Linear(768, 512)#config.hidden_size, config.hidden_size)
        self.dropout = nn.Dropout(0.5)
        self.out_proj = nn.Linear(512, 3)#config.hidden_size, config.num_labels)

    def forward(self, features, **kwargs):
        x = features
        x = self.dropout(x)
        x = self.dense(x)
        x = torch.tanh(x)
        x = self.dropout(x)
        x = self.out_proj(x)
        return x

class Classifier(nn.Module):
    def __init__(self, extractor):
        super().__init__()
        self.extractor = extractor
        self.classifier = ClassificationHead()
    def forward(self, x):
        features = self.extractor(torch.squeeze(x))
        features = features[0]
        res = torch.mean(features, dim=1)
        logit = self.classifier(res)
        return logit

# %%
from tqdm import tqdm
import math
from torch import autograd
import datetime

def train(model, opt, scheduler, loss_fn, epochs, data_tr, data_val, lr, last_epoch=0, data_augmentation = False, max_stable=15):
    best_val_loss = 1e9
    counter = 0
    augmented = '_augmented' if data_augmentation else ''
    nan=False
    for epoch in range(last_epoch, epochs):
        correct_predictions = 0
        count=0
        #tic = time()
        print('* Epoch %d/%d' % (epoch+1, epochs))

        avg_loss = 0
        model.train()  # train mode
        progress = tqdm(data_tr)
        for batch in progress:
            loss = 0
            # data to device
            X_batch, Y_batch = batch["representation"], batch["target"]
            # print(X_batch.shape)
            X_batch = X_batch.to(DEVICE)
            Y_batch = Y_batch.to(DEVICE)
            # set parameter gradients to zero
            opt.zero_grad()
            # forward
            Y_pred = model(X_batch)
            _, preds = torch.max(Y_pred, dim=1)
            preds = preds.to(DEVICE)
            Y_pred = Y_pred.to(DEVICE)

            loss = loss_fn(Y_pred, Y_batch)# forward-pass
            nan = math.isnan(loss)

            if nan:
              count=count+1
              nan=False
              continue
            correct_predictions += torch.sum(preds == Y_batch)
            progress.set_description(f'Loss: {loss:.2f} #nan->{count}')
            
            loss.backward()  # backward-pass
            opt.step()  # update weights
            if not scheduler is None:
                scheduler.step()
            # calculate loss to show the user
            avg_loss += loss
        avg_loss /= (len(data_tr)-(batch_size*count))
        avg_acc = correct_predictions.double() / ((len(data_tr)-count)*batch_size)
        
        print('loss: %f' % avg_loss)
        print('acc: %f' % avg_acc)
        # show intermediate results


        model.eval()  # testing mode
        val_loss = 0
        val_acc = 0
        print("start validation")
        count_loss_val=0
        progress_val = tqdm(data_val)
        correct_predictions_val = 0
        for v_b in progress_val:
            X_val, Y_val = v_b["representation"], v_b["target"]
            # X_val = X_val.to(DEVICE)#
            # Y_val = Y_val.to(DEVICE)#
            Y_hat = model(X_val.to(DEVICE)).detach().cpu()# detach and put into cpu
            
            _, preds_val = torch.max(Y_hat, dim=1)
            # preds_val = preds_val.to(DEVICE)#

            loss_val = loss_fn(Y_hat, Y_val)
            nan_loss = math.isnan(loss_val) #check loss==nan
            if nan_loss:
              count_loss_val = count_loss_val+1
              nan_loss = False
              continue
            #se trova un nan, salta tutto il batch
            correct_predictions_val += torch.sum(preds_val == Y_val)
            progress_val.set_description(f'Loss: {loss_val:.2f} #nan->{count_loss_val}')
            val_loss += loss_val

        val_loss /= (len(data_val)-(batch_size*count_loss_val))
        val_acc = correct_predictions_val.double() / ((len(data_val)-count_loss_val)*batch_size)
        print( f"validation loss: {val_loss}")
        print( f"validation accuracy: {val_acc}")
        if val_loss <= best_val_loss and val_loss > 0:
            counter = 0
            now = datetime.datetime.now()
            print(f'Save new model!- {now.day}/{now.month} h{now.hour+1}:{now.minute}')
            best_val_loss = val_loss
            torch.save(model.state_dict(), f'/content/drive/MyDrive/Tesi/Wav2vec2/final_80-20_NO-BALANCED_bandPass2_PATHOLOGY_3-class_wav2vec2_lr={lr}_batch={batch_size}_{freq}mhz_{duration}sec{augmented}.bin')
        else:
            counter += 1
        print("--------------------")
        if counter == max_stable:
            break

# %% [markdown]
# ----------------------------

# %%
from torch.utils.data import TensorDataset, DataLoader

freq=16
duration=20
train_ds = AudiosDataset(train_multiclass['filename'], train_multiclass['label'])
test_ds = AudiosDataset(test_multiclass['filename'], test_multiclass['label'])

batch_size = 2
num_workers = 10
loaders = {
    "train": DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        drop_last=True,
    ),
    "test": DataLoader(
        test_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        drop_last=True,
    ),
}
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# --------------
# Modello finale

# %%
from transformers import Wav2Vec2Model
DEVICE = 'cuda'
m = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")# torch.hub.load('s3prl/s3prl', 'audio_albert').to(DEVICE)
# Out:
# Downloading:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/360M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2Model: ['lm_head.bias', 'lm_head.weight']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = Classifier(m)

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi tanh dropout=0.7 batch=8 wav2vec2 FINAL
# Out:
# * Epoch 1/100
#   0%|          | 0/368 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 0.15 #nan->0: 100%|██████████| 368/368 [08:36<00:00,  1.40s/it]
# loss: 0.637399
# acc: 0.834239
# start validation
# Loss: 1.61 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.95it/s]
# validation loss: 0.4484102427959442
# validation accuracy: 0.8804347826086957
# Save new model!- 7/11 h24:43
# --------------------
# * Epoch 2/100
# Loss: 0.21 #nan->0: 100%|██████████| 368/368 [08:35<00:00,  1.40s/it]
# loss: 0.448767
# acc: 0.880435
# start validation
# Loss: 2.12 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.96it/s]
# validation loss: 0.38671886920928955
# validation accuracy: 0.8804347826086957
# Save new model!- 7/11 h24:52
# --------------------
# * Epoch 3/100
# Loss: 0.73 #nan->0: 100%|██████████| 368/368 [08:36<00:00,  1.40s/it]
# loss: 0.393764
# acc: 0.880435
# start validation
# Loss: 2.11 #nan->0: 100%|██████████| 92/92 [00:46<00:00,  1.96it/s]
# validation loss: 0.35317885875701904
# validation accuracy: 0.8804347826086957
# Save new model!- 8/11 h1:2
# --------------------
# * Epoch 4/100
# Loss: 0.03 #nan->0: 100%|██████████| 368/368 [08:34<00:00,  1.40s/it]
# loss: 0.328380
# acc: 0.880435
# start validation
# Loss: 1.12 #nan->0: 100%|██████████| 92/92 [00:46<00:00,  1.96it/s]
# validation loss: 0.30805134773254395
# validation accuracy: 0.8804347826086957
# Save new model!- 8/11 h1:11
# --------------------
# * Epoch 5/100
# Loss: 0.04 #nan->0: 100%|██████████| 368/368 [08:34<00:00,  1.40s/it]
# loss: 0.318105
# acc: 0.880435
# start validation
# Loss: 1.16 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.96it/s]
# validation loss: 0.2920369803905487
# validation accuracy: 0.8804347826086957
# Save new model!- 8/11 h1:21
# --------------------
# * Epoch 6/100
# Loss: 0.90 #nan->0: 100%|██████████| 368/368 [08:36<00:00,  1.40s/it]
# loss: 0.275652
# acc: 0.880435
# start validation
# Loss: 1.29 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.96it/s]
# validation loss: 0.29226815700531006
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 7/100
# Loss: 0.69 #nan->0: 100%|██████████| 368/368 [08:34<00:00,  1.40s/it]
# loss: 0.280099
# acc: 0.880435
# start validation
# Loss: 1.23 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.96it/s]
# validation loss: 0.2698386609554291
# validation accuracy: 0.8804347826086957
# Save new model!- 8/11 h1:39
# --------------------
# * Epoch 8/100
# Loss: 0.01 #nan->0: 100%|██████████| 368/368 [08:35<00:00,  1.40s/it]
# loss: 0.263055
# acc: 0.881793
# start validation
# Loss: 1.29 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.92it/s]
# validation loss: 0.26935192942619324
# validation accuracy: 0.8804347826086957
# Save new model!- 8/11 h1:49
# --------------------
# * Epoch 9/100
# Loss: 0.88 #nan->0: 100%|██████████| 368/368 [08:32<00:00,  1.39s/it]
# loss: 0.241371
# acc: 0.881793
# start validation
# Loss: 1.29 #nan->0: 100%|██████████| 92/92 [00:46<00:00,  1.97it/s]
# validation loss: 0.26934725046157837
# validation accuracy: 0.8804347826086957
# Save new model!- 8/11 h1:58
# --------------------
# * Epoch 10/100
# Loss: 0.01 #nan->0: 100%|██████████| 368/368 [08:34<00:00,  1.40s/it]
# loss: 0.247374
# acc: 0.876359
# start validation
# Loss: 1.31 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.94it/s]
# validation loss: 0.2794800400733948
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 11/100
# Loss: 0.01 #nan->0: 100%|██████████| 368/368 [08:36<00:00,  1.40s/it]
# loss: 0.263207
# acc: 0.885870
# start validation
# Loss: 1.27 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.93it/s]
# validation loss: 0.2792947590351105
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 12/100
# Loss: 0.01 #nan->0: 100%|██████████| 368/368 [08:38<00:00,  1.41s/it]
# loss: 0.235776
# acc: 0.877717
# start validation
# Loss: 1.25 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.94it/s]
# validation loss: 0.2768569886684418
# validation accuracy: 0.8695652173913043
# --------------------
# * Epoch 13/100
# Loss: 0.03 #nan->0: 100%|██████████| 368/368 [08:36<00:00,  1.40s/it]
# loss: 0.246686
# acc: 0.889946
# start validation
# Loss: 1.29 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.94it/s]
# validation loss: 0.2767166197299957
# validation accuracy: 0.8532608695652174
# --------------------
# * Epoch 14/100
# Loss: 0.01 #nan->0: 100%|██████████| 368/368 [08:37<00:00,  1.41s/it]
# loss: 0.250352
# acc: 0.889946
# start validation
# Loss: 1.31 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.95it/s]
# validation loss: 0.27654311060905457
# validation accuracy: 0.875
# --------------------
# * Epoch 15/100
# Loss: 0.53 #nan->0: 100%|██████████| 368/368 [08:37<00:00,  1.41s/it]
# loss: 0.223417
# acc: 0.887228
# start validation
# Loss: 1.34 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.94it/s]
# validation loss: 0.26520836353302
# validation accuracy: 0.8913043478260869
# Save new model!- 8/11 h2:55
# --------------------
# * Epoch 16/100
# Loss: 0.77 #nan->0: 100%|██████████| 368/368 [08:38<00:00,  1.41s/it]
# loss: 0.230459
# acc: 0.888587
# start validation
# Loss: 1.36 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.94it/s]
# validation loss: 0.2457515299320221
# validation accuracy: 0.9021739130434783
# Save new model!- 8/11 h3:4
# --------------------
# * Epoch 17/100
# Loss: 0.01 #nan->0: 100%|██████████| 368/368 [08:35<00:00,  1.40s/it]
# loss: 0.224294
# acc: 0.898098
# start validation
# Loss: 1.33 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.94it/s]
# validation loss: 0.2615087032318115
# validation accuracy: 0.8967391304347826
# --------------------
# * Epoch 18/100
# Loss: 0.84 #nan->0: 100%|██████████| 368/368 [08:34<00:00,  1.40s/it]
# loss: 0.223250
# acc: 0.889946
# start validation
# Loss: 1.36 #nan->0: 100%|██████████| 92/92 [00:47<00:00,  1.94it/s]
# validation loss: 0.2578389644622803
# validation accuracy: 0.875
# --------------------
# * Epoch 19/100
# Loss: 0.38 #nan->0:  20%|█▉        | 73/368 [01:42<06:54,  1.40s/it]

# %% [markdown]
# ### Tentativi precedenti

# %% [markdown]
# ---------------------
# BALANCED

# %%
from transformers import Wav2Vec2Model
DEVICE = 'cuda'
m = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")# torch.hub.load('s3prl/s3prl', 'audio_albert').to(DEVICE)
# Out:
# Downloading:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/360M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2Model: ['lm_head.weight', 'lm_head.bias']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = Classifier(m)

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2 FINAL
# Out:
# * Epoch 1/100
#   0%|          | 0/64 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 1.11 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 1.118090
# acc: 0.304688
# start validation
# Loss: 1.04 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 1.0852242708206177
# validation accuracy: 0.53125
# Save new model!- 1/11 h23:56
# --------------------
# * Epoch 2/100
# Loss: 0.99 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 1.070870
# acc: 0.406250
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 1.1247990131378174
# validation accuracy: 0.25
# --------------------
# * Epoch 3/100
# Loss: 1.22 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 1.055920
# acc: 0.460938
# start validation
# Loss: 0.96 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 1.0736310482025146
# validation accuracy: 0.46875
# Save new model!- 1/11 h23:59
# --------------------
# * Epoch 4/100
# Loss: 0.98 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 1.063868
# acc: 0.421875
# start validation
# Loss: 0.86 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.60it/s]
# validation loss: 1.0753304958343506
# validation accuracy: 0.5
# --------------------
# * Epoch 5/100
# Loss: 1.01 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 1.027192
# acc: 0.507812
# start validation
# Loss: 0.70 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.60it/s]
# validation loss: 0.9986487627029419
# validation accuracy: 0.59375
# Save new model!- 1/11 h24:3
# --------------------
# * Epoch 6/100
# Loss: 1.03 #nan->0: 100%|██████████| 64/64 [01:31<00:00,  1.43s/it]
# loss: 1.002741
# acc: 0.539062
# start validation
# Loss: 0.65 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.59it/s]
# validation loss: 0.9952408671379089
# validation accuracy: 0.5625
# Save new model!- 1/11 h24:4
# --------------------
# * Epoch 7/100
# Loss: 1.01 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.931894
# acc: 0.671875
# start validation
# Loss: 0.51 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.60it/s]
# validation loss: 0.9703471660614014
# validation accuracy: 0.59375
# Save new model!- 1/11 h24:6
# --------------------
# * Epoch 8/100
# Loss: 0.39 #nan->0: 100%|██████████| 64/64 [01:31<00:00,  1.44s/it]
# loss: 0.858483
# acc: 0.671875
# start validation
# Loss: 0.44 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.62it/s]
# validation loss: 0.8968223333358765
# validation accuracy: 0.59375
# Save new model!- 1/11 h24:8
# --------------------
# * Epoch 9/100
# Loss: 0.94 #nan->0: 100%|██████████| 64/64 [01:31<00:00,  1.43s/it]
# loss: 0.926181
# acc: 0.601562
# start validation
# Loss: 0.42 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.59it/s]
# validation loss: 0.8573613166809082
# validation accuracy: 0.625
# Save new model!- 1/11 h24:9
# --------------------
# * Epoch 10/100
# Loss: 1.45 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.45s/it]
# loss: 0.848994
# acc: 0.664062
# start validation
# Loss: 1.24 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.60it/s]
# validation loss: 1.1092063188552856
# validation accuracy: 0.46875
# --------------------
# * Epoch 11/100
# Loss: 1.26 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 0.867548
# acc: 0.664062
# start validation
# Loss: 0.33 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.58it/s]
# validation loss: 0.8360390663146973
# validation accuracy: 0.625
# Save new model!- 1/11 h24:13
# --------------------
# * Epoch 12/100
# Loss: 0.47 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 0.863119
# acc: 0.632812
# start validation
# Loss: 0.33 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.58it/s]
# validation loss: 0.8652100563049316
# validation accuracy: 0.59375
# --------------------
# * Epoch 13/100
# Loss: 0.31 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 0.816298
# acc: 0.710938
# start validation
# Loss: 0.30 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.57it/s]
# validation loss: 0.8525536060333252
# validation accuracy: 0.625
# --------------------
# * Epoch 14/100
# Loss: 1.02 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 0.786498
# acc: 0.687500
# start validation
# Loss: 0.29 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.60it/s]
# validation loss: 0.8363317251205444
# validation accuracy: 0.59375
# --------------------
# * Epoch 15/100
# Loss: 0.61 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.849285
# acc: 0.710938
# start validation
# Loss: 0.74 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 0.9597452282905579
# validation accuracy: 0.5
# --------------------
# * Epoch 16/100
# Loss: 0.34 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 0.727023
# acc: 0.726562
# start validation
# Loss: 0.27 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 0.8572152853012085
# validation accuracy: 0.59375
# --------------------
# * Epoch 17/100
# Loss: 0.55 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 0.763443
# acc: 0.703125
# start validation
# Loss: 0.27 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.57it/s]
# validation loss: 0.8047760725021362
# validation accuracy: 0.625
# Save new model!- 1/11 h24:23
# --------------------
# * Epoch 18/100
# Loss: 0.11 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 0.714378
# acc: 0.750000
# start validation
# Loss: 0.25 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.60it/s]
# validation loss: 0.859400749206543
# validation accuracy: 0.59375
# --------------------
# * Epoch 19/100
# Loss: 0.58 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.725725
# acc: 0.710938
# start validation
# Loss: 0.26 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 0.7812692523002625
# validation accuracy: 0.59375
# Save new model!- 1/11 h24:27
# --------------------
# * Epoch 20/100
# Loss: 0.36 #nan->0: 100%|██████████| 64/64 [01:31<00:00,  1.43s/it]
# loss: 0.697153
# acc: 0.718750
# start validation
# Loss: 0.25 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.57it/s]
# validation loss: 0.7827335000038147
# validation accuracy: 0.625
# --------------------
# * Epoch 21/100
# Loss: 0.79 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 0.706286
# acc: 0.726562
# start validation
# Loss: 0.24 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.60it/s]
# validation loss: 0.7507374286651611
# validation accuracy: 0.625
# Save new model!- 1/11 h24:30
# --------------------
# * Epoch 22/100
# Loss: 0.99 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 0.701401
# acc: 0.710938
# start validation
# Loss: 0.23 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.59it/s]
# validation loss: 0.7995450496673584
# validation accuracy: 0.625
# --------------------
# * Epoch 23/100
# Loss: 0.65 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.638425
# acc: 0.757812
# start validation
# Loss: 0.23 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.56it/s]
# validation loss: 0.6966941356658936
# validation accuracy: 0.65625
# Save new model!- 1/11 h24:34
# --------------------
# * Epoch 24/100
# Loss: 0.32 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 0.611278
# acc: 0.742188
# start validation
# Loss: 0.21 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.63it/s]
# validation loss: 0.767368495464325
# validation accuracy: 0.625
# --------------------
# * Epoch 25/100
# Loss: 0.11 #nan->0: 100%|██████████| 64/64 [01:31<00:00,  1.43s/it]
# loss: 0.584629
# acc: 0.773438
# start validation
# Loss: 0.20 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 0.7694751024246216
# validation accuracy: 0.625
# --------------------
# * Epoch 26/100
# Loss: 0.65 #nan->0: 100%|██████████| 64/64 [01:31<00:00,  1.43s/it]
# loss: 0.634916
# acc: 0.750000
# start validation
# Loss: 0.19 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.60it/s]
# validation loss: 0.7853819727897644
# validation accuracy: 0.625
# --------------------
# * Epoch 27/100
# Loss: 0.09 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 0.593145
# acc: 0.765625
# start validation
# Loss: 0.20 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.56it/s]
# validation loss: 0.7913010120391846
# validation accuracy: 0.625
# --------------------
# * Epoch 28/100
# Loss: 2.02 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.44s/it]
# loss: 0.704626
# acc: 0.726562
# start validation
# Loss: 0.23 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.57it/s]
# validation loss: 0.6874486207962036
# validation accuracy: 0.65625
# Save new model!- 1/11 h24:42
# --------------------
# * Epoch 29/100
# Loss: 0.29 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.45s/it]
# loss: 0.624567
# acc: 0.734375
# start validation
# Loss: 0.21 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 0.6874219179153442
# validation accuracy: 0.65625
# Save new model!- 1/11 h24:44
# --------------------
# * Epoch 30/100
# Loss: 0.25 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.615547
# acc: 0.750000
# start validation
# Loss: 0.19 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 0.6890892386436462
# validation accuracy: 0.65625
# --------------------
# * Epoch 31/100
# Loss: 0.41 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.564295
# acc: 0.757812
# start validation
# Loss: 0.18 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.60it/s]
# validation loss: 0.6851956248283386
# validation accuracy: 0.65625
# Save new model!- 1/11 h24:47
# --------------------
# * Epoch 32/100
# Loss: 0.92 #nan->0: 100%|██████████| 64/64 [01:32<00:00,  1.45s/it]
# loss: 0.596411
# acc: 0.750000
# start validation
# Loss: 0.21 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.49it/s]
# validation loss: 0.6516851186752319
# validation accuracy: 0.65625
# Save new model!- 1/11 h24:49
# --------------------
# * Epoch 33/100
# Loss: 1.22 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.585592
# acc: 0.750000
# start validation
# Loss: 0.21 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.59it/s]
# validation loss: 0.6605271100997925
# validation accuracy: 0.65625
# --------------------
# * Epoch 34/100
# Loss: 1.31 #nan->0: 100%|██████████| 64/64 [01:33<00:00,  1.46s/it]
# loss: 0.607455
# acc: 0.757812
# start validation
# Loss: 0.18 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.56it/s]
# validation loss: 0.6945012807846069
# validation accuracy: 0.65625
# --------------------
# * Epoch 35/100
# Loss: 0.55 #nan->0:   2%|▏         | 1/64 [00:04<04:22,  4.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-f5e65e6566a1> in <module>()
#       7 optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
#       8 scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
# ----> 9 train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#      10 #16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2 FINAL
#
# <ipython-input-32-b67c210a2e44> in train(model, opt, scheduler, loss_fn, epochs, data_tr, data_val, lr, last_epoch, data_augmentation, max_stable)
#      34
#      35             loss = loss_fn(Y_pred, Y_batch)# forward-pass
# ---> 36             nan = math.isnan(loss)
#      37
#      38             if nan:
#
# KeyboardInterrupt:

# %%
# train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr, last_epoch=48)

# %% [markdown]
# --------------------------

# %% [markdown]
# -----------------------------

# %% [markdown]
# ------------------------------------

# %%
DEVICE = 'cuda'
model.load_state_dict(torch.load('/content/drive/MyDrive/Tesi/Wav2vec2/final_80-20_BALANCED_bandPass2_PATHOLOGY_3-class_wav2vec2_lr=1e-06_batch=2_16mhz_20sec.bin'))
max_epochs = 100
model = model.to(DEVICE)
lr =1e-6
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr, last_epoch=58)
#16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2 FINAL
# Out:
# * Epoch 59/100
#   0%|          | 0/64 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 0.75 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.878374
# acc: 0.632812
# start validation
# Loss: 1.00 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.71it/s]
# validation loss: 0.901862621307373
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:13
# --------------------
# * Epoch 60/100
# Loss: 0.79 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.34s/it]
# loss: 0.911873
# acc: 0.554688
# start validation
# Loss: 0.97 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 0.8649992942810059
# validation accuracy: 0.59375
# Save new model!- 1/11 h17:15
# --------------------
# * Epoch 61/100
# Loss: 0.46 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.873417
# acc: 0.640625
# start validation
# Loss: 0.98 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.880689799785614
# validation accuracy: 0.53125
# --------------------
# * Epoch 62/100
# Loss: 1.00 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.866359
# acc: 0.554688
# start validation
# Loss: 1.00 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.8972400426864624
# validation accuracy: 0.46875
# --------------------
# * Epoch 63/100
# Loss: 1.03 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.834709
# acc: 0.625000
# start validation
# Loss: 1.04 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 0.8641980886459351
# validation accuracy: 0.5
# Save new model!- 1/11 h17:19
# --------------------
# * Epoch 64/100
# Loss: 0.75 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.866019
# acc: 0.593750
# start validation
# Loss: 1.04 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.8552587628364563
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:21
# --------------------
# * Epoch 65/100
# Loss: 0.71 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.833383
# acc: 0.656250
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 0.869240403175354
# validation accuracy: 0.53125
# --------------------
# * Epoch 66/100
# Loss: 1.02 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.803056
# acc: 0.664062
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.8450248837471008
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:24
# --------------------
# * Epoch 67/100
# Loss: 0.80 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.837844
# acc: 0.687500
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.8559826612472534
# validation accuracy: 0.53125
# --------------------
# * Epoch 68/100
# Loss: 0.49 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.854843
# acc: 0.632812
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.8629642724990845
# validation accuracy: 0.53125
# --------------------
# * Epoch 69/100
# Loss: 0.68 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.796118
# acc: 0.671875
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.71it/s]
# validation loss: 0.8575524091720581
# validation accuracy: 0.53125
# --------------------
# * Epoch 70/100
# Loss: 0.84 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.39s/it]
# loss: 0.827036
# acc: 0.640625
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.8427367806434631
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:31
# --------------------
# * Epoch 71/100
# Loss: 0.59 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.828635
# acc: 0.679688
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.8331866264343262
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:33
# --------------------
# * Epoch 72/100
# Loss: 0.36 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.803059
# acc: 0.695312
# start validation
# Loss: 1.04 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.8672151565551758
# validation accuracy: 0.5
# --------------------
# * Epoch 73/100
# Loss: 0.36 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.808796
# acc: 0.687500
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.8269208669662476
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:36
# --------------------
# * Epoch 74/100
# Loss: 1.13 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.785730
# acc: 0.703125
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.822070300579071
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:37
# --------------------
# * Epoch 75/100
# Loss: 1.05 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.807290
# acc: 0.703125
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.8220484256744385
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:39
# --------------------
# * Epoch 76/100
# Loss: 0.72 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.799876
# acc: 0.679688
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.8205127716064453
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:41
# --------------------
# * Epoch 77/100
# Loss: 0.74 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.794372
# acc: 0.710938
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 0.8250536322593689
# validation accuracy: 0.53125
# --------------------
# * Epoch 78/100
# Loss: 0.49 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.814366
# acc: 0.671875
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.8367268443107605
# validation accuracy: 0.53125
# --------------------
# * Epoch 79/100
# Loss: 0.16 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.763671
# acc: 0.695312
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.8153814077377319
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:46
# --------------------
# * Epoch 80/100
# Loss: 0.61 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.782314
# acc: 0.703125
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.63it/s]
# validation loss: 0.8971225023269653
# validation accuracy: 0.46875
# --------------------
# * Epoch 81/100
# Loss: 0.36 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.790004
# acc: 0.710938
# start validation
# Loss: 1.04 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.8142014145851135
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:49
# --------------------
# * Epoch 82/100
# Loss: 1.73 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.782298
# acc: 0.710938
# start validation
# Loss: 1.06 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 0.860705554485321
# validation accuracy: 0.5
# --------------------
# * Epoch 83/100
# Loss: 0.54 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.799398
# acc: 0.718750
# start validation
# Loss: 1.06 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 0.8181570172309875
# validation accuracy: 0.53125
# --------------------
# * Epoch 84/100
# Loss: 0.93 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.36s/it]
# loss: 0.767309
# acc: 0.671875
# start validation
# Loss: 1.07 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.71it/s]
# validation loss: 0.8482970595359802
# validation accuracy: 0.5
# --------------------
# * Epoch 85/100
# Loss: 0.21 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.763817
# acc: 0.703125
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.8849606513977051
# validation accuracy: 0.46875
# --------------------
# * Epoch 86/100
# Loss: 0.16 #nan->0: 100%|██████████| 64/64 [01:29<00:00,  1.39s/it]
# loss: 0.739174
# acc: 0.703125
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.55it/s]
# validation loss: 0.8130439519882202
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:57
# --------------------
# * Epoch 87/100
# Loss: 0.67 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.753562
# acc: 0.726562
# start validation
# Loss: 1.06 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.8110363483428955
# validation accuracy: 0.53125
# Save new model!- 1/11 h17:59
# --------------------
# * Epoch 88/100
# Loss: 0.80 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.768556
# acc: 0.695312
# start validation
# Loss: 1.06 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.8551760911941528
# validation accuracy: 0.5
# --------------------
# * Epoch 89/100
# Loss: 0.47 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.776934
# acc: 0.703125
# start validation
# Loss: 1.08 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 0.804185688495636
# validation accuracy: 0.53125
# Save new model!- 1/11 h18:2
# --------------------
# * Epoch 90/100
# Loss: 0.59 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.763166
# acc: 0.718750
# start validation
# Loss: 1.08 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.81235271692276
# validation accuracy: 0.53125
# --------------------
# * Epoch 91/100
# Loss: 0.82 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.783435
# acc: 0.687500
# start validation
# Loss: 1.10 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 0.8006091117858887
# validation accuracy: 0.5625
# Save new model!- 1/11 h18:5
# --------------------
# * Epoch 92/100
# Loss: 0.24 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.765434
# acc: 0.750000
# start validation
# Loss: 1.11 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.7867649793624878
# validation accuracy: 0.5625
# Save new model!- 1/11 h18:7
# --------------------
# * Epoch 93/100
# Loss: 1.12 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.36s/it]
# loss: 0.756763
# acc: 0.710938
# start validation
# Loss: 1.11 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 0.7950029373168945
# validation accuracy: 0.5625
# --------------------
# * Epoch 94/100
# Loss: 0.09 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.715284
# acc: 0.710938
# start validation
# Loss: 1.09 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.7994958758354187
# validation accuracy: 0.5625
# --------------------
# * Epoch 95/100
# Loss: 1.52 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.754238
# acc: 0.687500
# start validation
# Loss: 1.09 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 0.9035834074020386
# validation accuracy: 0.46875
# --------------------
# * Epoch 96/100
# Loss: 1.19 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.36s/it]
# loss: 0.755103
# acc: 0.687500
# start validation
# Loss: 1.09 #nan->0: 100%|██████████| 16/16 [00:10<00:00,  1.60it/s]
# validation loss: 0.8153088092803955
# validation accuracy: 0.5625
# --------------------
# * Epoch 97/100
# Loss: 0.81 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.36s/it]
# loss: 0.745847
# acc: 0.703125
# start validation
# Loss: 1.11 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.7989791035652161
# validation accuracy: 0.53125
# --------------------

# %% [markdown]
# --------------------------

# %%
from transformers import Wav2Vec2Model
DEVICE = 'cuda'
m = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")# torch.hub.load('s3prl/s3prl', 'audio_albert').to(DEVICE)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2Model: ['lm_head.weight', 'lm_head.bias']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = Classifier(m)

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2 FINAL
# Out:
# * Epoch 1/100
#   0%|          | 0/64 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 1.22 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.099926
# acc: 0.312500
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.61it/s]
# validation loss: 1.0886024236679077
# validation accuracy: 0.46875
# Save new model!- 1/11 h18:23
# --------------------
# * Epoch 2/100
# Loss: 0.97 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.080604
# acc: 0.382812
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0842814445495605
# validation accuracy: 0.46875
# Save new model!- 1/11 h18:25
# --------------------
# * Epoch 3/100
# Loss: 1.16 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.078194
# acc: 0.460938
# start validation
# Loss: 1.03 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.0770260095596313
# validation accuracy: 0.46875
# Save new model!- 1/11 h18:27
# --------------------
# * Epoch 4/100
# Loss: 0.94 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.068401
# acc: 0.414062
# start validation
# Loss: 1.03 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.64it/s]
# validation loss: 1.0728756189346313
# validation accuracy: 0.46875
# Save new model!- 1/11 h18:28
# --------------------
# * Epoch 5/100
# Loss: 1.22 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.055592
# acc: 0.453125
# start validation
# Loss: 0.96 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.094100832939148
# validation accuracy: 0.46875
# --------------------
# * Epoch 6/100
# Loss: 1.00 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.052786
# acc: 0.453125
# start validation
# Loss: 0.95 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 1.084867238998413
# validation accuracy: 0.46875
# --------------------
# * Epoch 7/100
# Loss: 0.85 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.055349
# acc: 0.460938
# start validation
# Loss: 0.95 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.0920846462249756
# validation accuracy: 0.46875
# --------------------
# * Epoch 8/100
# Loss: 0.90 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.051298
# acc: 0.468750
# start validation
# Loss: 0.94 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.0966212749481201
# validation accuracy: 0.5
# --------------------
# * Epoch 9/100
# Loss: 1.65 #nan->0: 100%|██████████| 64/64 [01:25<00:00,  1.34s/it]
# loss: 1.029742
# acc: 0.492188
# start validation
# Loss: 0.92 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 1.1156688928604126
# validation accuracy: 0.46875
# --------------------

# %%
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr, last_epoch=9)
# Out:
# * Epoch 10/100
#   0%|          | 0/64 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 1.31 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.046368
# acc: 0.453125
# start validation
# Loss: 0.87 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.1217349767684937
# validation accuracy: 0.46875
# Save new model!- 1/11 h18:58
# --------------------
# * Epoch 11/100
# Loss: 0.74 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.044203
# acc: 0.515625
# start validation
# Loss: 0.94 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.64it/s]
# validation loss: 1.0768901109695435
# validation accuracy: 0.40625
# Save new model!- 1/11 h18:59
# --------------------
# * Epoch 12/100
# Loss: 1.14 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.055395
# acc: 0.453125
# start validation
# Loss: 0.90 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.0838580131530762
# validation accuracy: 0.46875
# --------------------
# * Epoch 13/100
# Loss: 1.42 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.031055
# acc: 0.460938
# start validation
# Loss: 0.84 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.0279712677001953
# validation accuracy: 0.46875
# Save new model!- 1/11 h19:3
# --------------------
# * Epoch 14/100
# Loss: 0.86 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.991952
# acc: 0.546875
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 1.092522144317627
# validation accuracy: 0.34375
# --------------------
# * Epoch 15/100
# Loss: 0.98 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.019266
# acc: 0.554688
# start validation
# Loss: 0.99 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.135746955871582
# validation accuracy: 0.46875
# --------------------
# * Epoch 16/100
# Loss: 1.25 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.071004
# acc: 0.468750
# start validation
# Loss: 1.00 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.111391305923462
# validation accuracy: 0.25
# --------------------
# * Epoch 17/100
# Loss: 1.16 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.071031
# acc: 0.421875
# start validation
# Loss: 0.94 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0942883491516113
# validation accuracy: 0.46875
# --------------------
# * Epoch 18/100
# Loss: 0.73 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.025783
# acc: 0.476562
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.64it/s]
# validation loss: 1.138440728187561
# validation accuracy: 0.46875
# --------------------
# * Epoch 19/100
# Loss: 0.64 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.049977
# acc: 0.437500
# start validation
# Loss: 0.93 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 1.1364237070083618
# validation accuracy: 0.46875
# --------------------
# * Epoch 20/100
# Loss: 1.13 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.051628
# acc: 0.421875
# start validation
# Loss: 0.90 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.118613362312317
# validation accuracy: 0.46875
# --------------------
# * Epoch 21/100
# Loss: 1.37 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.059245
# acc: 0.460938
# start validation
# Loss: 0.93 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.62it/s]
# validation loss: 1.0942014455795288
# validation accuracy: 0.46875
# --------------------
# * Epoch 22/100
# Loss: 0.91 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.038286
# acc: 0.476562
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0877872705459595
# validation accuracy: 0.46875
# --------------------
# * Epoch 23/100
# Loss: 0.59 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.039521
# acc: 0.476562
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.64it/s]
# validation loss: 1.0905224084854126
# validation accuracy: 0.46875
# --------------------
# * Epoch 24/100
# Loss: 1.29 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.055035
# acc: 0.437500
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 1.1036090850830078
# validation accuracy: 0.46875
# --------------------
# * Epoch 25/100
# Loss: 0.72 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.044816
# acc: 0.468750
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.63it/s]
# validation loss: 1.0880531072616577
# validation accuracy: 0.46875
# --------------------
# * Epoch 26/100
# Loss: 0.68 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.045918
# acc: 0.484375
# start validation
# Loss: 0.89 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0484970808029175
# validation accuracy: 0.46875
# --------------------
# * Epoch 27/100
# Loss: 0.96 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 1.030854
# acc: 0.500000
# start validation
# Loss: 0.96 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0761593580245972
# validation accuracy: 0.375
# --------------------
# * Epoch 28/100
# Loss: 1.42 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.053157
# acc: 0.445312
# start validation
# Loss: 0.93 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0806673765182495
# validation accuracy: 0.46875
# --------------------

# %%
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr,last_epoch=28)
# Out:
# * Epoch 29/100
#   0%|          | 0/64 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 0.79 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 1.025391
# acc: 0.468750
# start validation
# Loss: 0.96 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 1.0347161293029785
# validation accuracy: 0.375
# Save new model!- 1/11 h19:45
# --------------------
# * Epoch 30/100
# Loss: 1.31 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.970936
# acc: 0.500000
# start validation
# Loss: 0.97 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 1.0850156545639038
# validation accuracy: 0.5
# --------------------
# * Epoch 31/100
# Loss: 0.97 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.067049
# acc: 0.460938
# start validation
# Loss: 0.92 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0248464345932007
# validation accuracy: 0.5
# Save new model!- 1/11 h19:48
# --------------------
# * Epoch 32/100
# Loss: 1.16 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.052436
# acc: 0.414062
# start validation
# Loss: 0.98 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.0799223184585571
# validation accuracy: 0.53125
# --------------------
# * Epoch 33/100
# Loss: 0.79 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 1.022250
# acc: 0.460938
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.0988625288009644
# validation accuracy: 0.5
# --------------------
# * Epoch 34/100
# Loss: 1.17 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.989799
# acc: 0.546875
# start validation
# Loss: 0.93 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.0484886169433594
# validation accuracy: 0.40625
# --------------------
# * Epoch 35/100
# Loss: 1.01 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.34s/it]
# loss: 1.072103
# acc: 0.414062
# start validation
# Loss: 0.89 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.64it/s]
# validation loss: 1.1140443086624146
# validation accuracy: 0.46875
# --------------------
# * Epoch 36/100
# Loss: 0.93 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 1.041549
# acc: 0.445312
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 1.080042839050293
# validation accuracy: 0.46875
# --------------------
# * Epoch 37/100
# Loss: 0.71 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 1.028705
# acc: 0.445312
# start validation
# Loss: 1.00 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.0219837427139282
# validation accuracy: 0.4375
# Save new model!- 1/11 h19:58
# --------------------
# * Epoch 38/100
# Loss: 1.39 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.997325
# acc: 0.500000
# start validation
# Loss: 0.76 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 0.9977244734764099
# validation accuracy: 0.53125
# Save new model!- 1/11 h19:59
# --------------------
# * Epoch 39/100
# Loss: 0.85 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.991154
# acc: 0.523438
# start validation
# Loss: 0.69 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 1.0086126327514648
# validation accuracy: 0.53125
# --------------------
# * Epoch 40/100
# Loss: 0.66 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.972227
# acc: 0.562500
# start validation
# Loss: 0.84 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.64it/s]
# validation loss: 1.0116539001464844
# validation accuracy: 0.5
# --------------------
# * Epoch 41/100
# Loss: 0.70 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.36s/it]
# loss: 0.980774
# acc: 0.539062
# start validation
# Loss: 1.00 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.1640864610671997
# validation accuracy: 0.46875
# --------------------
# * Epoch 42/100
# Loss: 0.64 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.965171
# acc: 0.546875
# start validation
# Loss: 0.56 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.006691575050354
# validation accuracy: 0.5
# --------------------
# * Epoch 43/100
# Loss: 0.55 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 1.056935
# acc: 0.500000
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.1504878997802734
# validation accuracy: 0.4375
# --------------------
# * Epoch 44/100
# Loss: 0.95 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.998196
# acc: 0.539062
# start validation
# Loss: 0.89 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.65it/s]
# validation loss: 1.0619386434555054
# validation accuracy: 0.46875
# --------------------
# * Epoch 45/100
# Loss: 1.04 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.953068
# acc: 0.562500
# start validation
# Loss: 0.66 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.9616587162017822
# validation accuracy: 0.53125
# Save new model!- 1/11 h20:11
# --------------------
# * Epoch 46/100
# Loss: 1.18 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.020027
# acc: 0.476562
# start validation
# Loss: 1.08 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 1.1084675788879395
# validation accuracy: 0.3125
# --------------------
# * Epoch 47/100
# Loss: 0.99 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.991635
# acc: 0.531250
# start validation
# Loss: 0.98 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.9386674761772156
# validation accuracy: 0.5
# Save new model!- 1/11 h20:14
# --------------------
# * Epoch 48/100
# Loss: 0.85 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.966617
# acc: 0.500000
# start validation
# Loss: 0.97 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.9202102422714233
# validation accuracy: 0.5
# Save new model!- 1/11 h20:16
# --------------------
# * Epoch 49/100
# Loss: 1.38 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.903714
# acc: 0.609375
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.9017802476882935
# validation accuracy: 0.5
# Save new model!- 1/11 h20:17
# --------------------
# * Epoch 50/100
# Loss: 0.83 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.928329
# acc: 0.554688
# start validation
# Loss: 1.12 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 1.064582347869873
# validation accuracy: 0.5
# --------------------
# * Epoch 51/100
# Loss: 0.86 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 1.129198
# acc: 0.460938
# start validation
# Loss: 0.92 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.0646226406097412
# validation accuracy: 0.5
# --------------------
# * Epoch 52/100
# Loss: 1.16 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.36s/it]
# loss: 1.057428
# acc: 0.492188
# start validation
# Loss: 0.90 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.72it/s]
# validation loss: 1.0658029317855835
# validation accuracy: 0.5
# --------------------
# * Epoch 53/100
# Loss: 1.00 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 1.003247
# acc: 0.515625
# start validation
# Loss: 0.84 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 1.0115445852279663
# validation accuracy: 0.53125
# --------------------
# * Epoch 54/100
# Loss: 0.94 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.972619
# acc: 0.515625
# start validation
# Loss: 1.01 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# validation loss: 1.083268642425537
# validation accuracy: 0.34375
# --------------------
# * Epoch 55/100
# Loss: 1.07 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 1.026127
# acc: 0.445312
# start validation
# Loss: 0.97 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.70it/s]
# validation loss: 1.0526695251464844
# validation accuracy: 0.34375
# --------------------
# * Epoch 56/100
# Loss: 0.90 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.968445
# acc: 0.523438
# start validation
# Loss: 0.95 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.004239559173584
# validation accuracy: 0.40625
# --------------------
# * Epoch 57/100
# Loss: 0.87 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.981932
# acc: 0.515625
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.0058534145355225
# validation accuracy: 0.46875
# --------------------
# * Epoch 58/100
# Loss: 1.51 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.36s/it]
# loss: 0.955847
# acc: 0.585938
# start validation
# Loss: 1.01 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.006712555885315
# validation accuracy: 0.5
# --------------------
# * Epoch 59/100
# Loss: 1.70 #nan->0: 100%|██████████| 64/64 [01:26<00:00,  1.35s/it]
# loss: 0.954035
# acc: 0.554688
# start validation
# Loss: 1.04 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.71it/s]
# validation loss: 0.9426712393760681
# validation accuracy: 0.5
# --------------------
# * Epoch 60/100
# Loss: 1.30 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.964965
# acc: 0.554688
# start validation
# Loss: 0.89 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 1.0511877536773682
# validation accuracy: 0.5
# --------------------
# * Epoch 61/100
# Loss: 0.64 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.982233
# acc: 0.570312
# start validation
# Loss: 0.76 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 1.0411860942840576
# validation accuracy: 0.5
# --------------------
# * Epoch 62/100
# Loss: 1.07 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.37s/it]
# loss: 0.958765
# acc: 0.554688
# start validation
# Loss: 0.96 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.68it/s]
# validation loss: 0.9698647856712341
# validation accuracy: 0.5
# --------------------
# * Epoch 63/100
# Loss: 1.75 #nan->0: 100%|██████████| 64/64 [01:27<00:00,  1.36s/it]
# loss: 0.876470
# acc: 0.625000
# start validation
# Loss: 1.14 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.66it/s]
# validation loss: 0.9791899919509888
# validation accuracy: 0.5
# --------------------
# * Epoch 64/100
# Loss: 2.05 #nan->0: 100%|██████████| 64/64 [01:28<00:00,  1.38s/it]
# loss: 0.893598
# acc: 0.601562
# start validation
# Loss: 0.42 #nan->0: 100%|██████████| 16/16 [00:09<00:00,  1.67it/s]
# validation loss: 0.9879645109176636
# validation accuracy: 0.5625
# --------------------

# %% [markdown]
# ------------------

# %% [markdown]
# --------------------------

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2 FINAL
# Out:
# * Epoch 1/100
#   0%|          | 0/368 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 1.28 #nan->0: 100%|██████████| 368/368 [08:04<00:00,  1.32s/it]
# loss: 0.609615
# acc: 0.845109
# start validation
# Loss: 1.35 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.08it/s]
# validation loss: 0.42754703760147095
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h22:27
# --------------------
# * Epoch 2/100
# Loss: 0.31 #nan->0: 100%|██████████| 368/368 [08:02<00:00,  1.31s/it]
# loss: 0.463562
# acc: 0.880435
# start validation
# Loss: 1.22 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.08it/s]
# validation loss: 0.5325791239738464
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 3/100
# Loss: 0.12 #nan->0: 100%|██████████| 368/368 [08:04<00:00,  1.32s/it]
# loss: 0.431611
# acc: 0.880435
# start validation
# Loss: 1.18 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.07it/s]
# validation loss: 0.41626614332199097
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h22:45
# --------------------
# * Epoch 4/100
# Loss: 0.05 #nan->0: 100%|██████████| 368/368 [08:06<00:00,  1.32s/it]
# loss: 0.389021
# acc: 0.880435
# start validation
# Loss: 2.53 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.07it/s]
# validation loss: 0.38113775849342346
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h22:54
# --------------------
# * Epoch 5/100
# Loss: 0.03 #nan->0: 100%|██████████| 368/368 [08:03<00:00,  1.31s/it]
# loss: 0.362454
# acc: 0.880435
# start validation
# Loss: 1.56 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.07it/s]
# validation loss: 0.35369324684143066
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h23:2
# --------------------
# * Epoch 6/100
# Loss: 0.13 #nan->0: 100%|██████████| 368/368 [08:02<00:00,  1.31s/it]
# loss: 0.342742
# acc: 0.880435
# start validation
# Loss: 1.16 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.08it/s]
# validation loss: 0.3207084536552429
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h23:11
# --------------------
# * Epoch 7/100
# Loss: 0.02 #nan->0: 100%|██████████| 368/368 [08:03<00:00,  1.31s/it]
# loss: 0.303486
# acc: 0.880435
# start validation
# Loss: 1.28 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.08it/s]
# validation loss: 0.3806048333644867
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 8/100
# Loss: 0.23 #nan->0: 100%|██████████| 368/368 [08:06<00:00,  1.32s/it]
# loss: 0.316499
# acc: 0.879076
# start validation
# Loss: 1.33 #nan->0: 100%|██████████| 92/92 [00:44<00:00,  2.07it/s]
# validation loss: 0.30000635981559753
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h23:29
# --------------------
# * Epoch 9/100
# Loss: 0.70 #nan->0: 100%|██████████| 368/368 [08:05<00:00,  1.32s/it]
# loss: 0.281702
# acc: 0.880435
# start validation
# Loss: 1.27 #nan->0: 100%|██████████| 92/92 [00:43<00:00,  2.10it/s]
# validation loss: 0.2831314206123352
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h23:38
# --------------------
# * Epoch 10/100
# Loss: 0.05 #nan->0: 100%|██████████| 368/368 [08:03<00:00,  1.31s/it]
# loss: 0.300160
# acc: 0.877717
# start validation
# Loss: 1.27 #nan->0: 100%|██████████| 92/92 [00:43<00:00,  2.10it/s]
# validation loss: 0.28315967321395874
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 11/100
# Loss: 0.02 #nan->0:  46%|████▌     | 169/368 [03:46<04:27,  1.34s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-f5e65e6566a1> in <module>()
#       7 optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
#       8 scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
# ----> 9 train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#      10 #16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2 FINAL
#
# <ipython-input-31-e81c7b961352> in train(model, opt, scheduler, loss_fn, epochs, data_tr, data_val, lr, last_epoch, data_augmentation, max_stable)
#      28             opt.zero_grad()
#      29             # forward
# ---> 30             Y_pred = model(X_batch)
#      31             _, preds = torch.max(Y_pred, dim=1)
#      32             preds = preds.to(DEVICE)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-28-95b0a4efc1a7> in forward(self, x)
#      34         #             )
#      35     def forward(self, x):
# ---> 36         features = self.extractor(torch.squeeze(x))
#      37         features = features[0]#torch.stack(list(features['last_hidden_state']))
#      38         res = torch.mean(features, dim=1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in forward(self, input_values, attention_mask, mask_time_indices, output_attentions, output_hidden_states, return_dict)
#    1071         hidden_states, extract_features = self.feature_projection(extract_features)
#    1072         hidden_states = self._mask_hidden_states(
# -> 1073             hidden_states, mask_time_indices=mask_time_indices, attention_mask=attention_mask
#    1074         )
#    1075
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in _mask_hidden_states(self, hidden_states, mask_time_indices, attention_mask)
#    1004                 device=hidden_states.device,
#    1005                 attention_mask=attention_mask,
# -> 1006                 min_masks=2,
#    1007             )
#    1008             hidden_states[mask_time_indices] = self.masked_spec_embed.to(hidden_states.dtype)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in _compute_mask_indices(shape, mask_prob, mask_length, device, attention_mask, min_masks)
#     165
#     166     # get random indices to mask
# --> 167     spec_aug_mask_idxs = torch.multinomial(uniform_dist, num_masked_spans)
#     168
#     169     # expand masked indices to masked spans
#
# KeyboardInterrupt:

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-4
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2
# Out:
# * Epoch 1/100
#   0%|          | 0/368 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 0.20 #nan->0: 100%|██████████| 368/368 [08:08<00:00,  1.33s/it]
# loss: 0.581917
# acc: 0.861413
# start validation
# Loss: 1.85 #nan->0: 100%|██████████| 92/92 [00:45<00:00,  2.01it/s]
# validation loss: 0.46562525629997253
# validation accuracy: 0.8804347826086957
# Save new model!- 26/10 h19:17
# --------------------
# * Epoch 2/100
# Loss: 0.12 #nan->0: 100%|██████████| 368/368 [08:12<00:00,  1.34s/it]
# loss: 0.472410
# acc: 0.880435
# start validation
# Loss: 2.06 #nan->0: 100%|██████████| 92/92 [00:45<00:00,  2.02it/s]
# validation loss: 0.4757501482963562
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 3/100
# Loss: 0.15 #nan->0: 100%|██████████| 368/368 [08:09<00:00,  1.33s/it]
# loss: 0.467059
# acc: 0.880435
# start validation
# Loss: 2.16 #nan->0: 100%|██████████| 92/92 [00:45<00:00,  2.02it/s]
# validation loss: 0.489655464887619
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 4/100
# Loss: 0.13 #nan->0: 100%|██████████| 368/368 [08:12<00:00,  1.34s/it]
# loss: 0.466076
# acc: 0.880435
# start validation
# Loss: 1.94 #nan->0: 100%|██████████| 92/92 [00:45<00:00,  2.02it/s]
# validation loss: 0.46734365820884705
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 5/100
# Loss: 1.75 #nan->0:  16%|█▌        | 59/368 [01:20<07:02,  1.37s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-db07f59c0101> in <module>()
#       7 optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
#       8 scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
# ----> 9 train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#      10 #16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2
#
# <ipython-input-32-2354d778ad04> in train(model, opt, scheduler, loss_fn, epochs, data_tr, data_val, lr, last_epoch, data_augmentation, max_stable)
#      28             opt.zero_grad()
#      29             # forward
# ---> 30             Y_pred = model(X_batch)
#      31             _, preds = torch.max(Y_pred, dim=1)
#      32             preds = preds.to(DEVICE)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-29-e63cb2fa4a31> in forward(self, x)
#      34         #             )
#      35     def forward(self, x):
# ---> 36         features = self.extractor(torch.squeeze(x))
#      37         features = features[0]#torch.stack(list(features['last_hidden_state']))
#      38         res = torch.mean(features, dim=1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in forward(self, input_values, attention_mask, mask_time_indices, output_attentions, output_hidden_states, return_dict)
#    1071         hidden_states, extract_features = self.feature_projection(extract_features)
#    1072         hidden_states = self._mask_hidden_states(
# -> 1073             hidden_states, mask_time_indices=mask_time_indices, attention_mask=attention_mask
#    1074         )
#    1075
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in _mask_hidden_states(self, hidden_states, mask_time_indices, attention_mask)
#    1004                 device=hidden_states.device,
#    1005                 attention_mask=attention_mask,
# -> 1006                 min_masks=2,
#    1007             )
#    1008             hidden_states[mask_time_indices] = self.masked_spec_embed.to(hidden_states.dtype)
#
# /usr/local/lib/python3.7/dist-packages/transformers/models/wav2vec2/modeling_wav2vec2.py in _compute_mask_indices(shape, mask_prob, mask_length, device, attention_mask, min_masks)
#     165
#     166     # get random indices to mask
# --> 167     spec_aug_mask_idxs = torch.multinomial(uniform_dist, num_masked_spans)
#     168
#     169     # expand masked indices to masked spans
#
# KeyboardInterrupt:

# %% [markdown]
# ---------------------------

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi sigmoid dropout=0.7 batch=8 wav2vec2
# Out:
# * Epoch 1/100
#   0%|          | 0/368 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 0.42 #nan->0: 100%|██████████| 368/368 [08:44<00:00,  1.43s/it]
# loss: 0.930802
# acc: 0.763587
# start validation
# Loss: 1.43 #nan->0: 100%|██████████| 92/92 [00:48<00:00,  1.90it/s]
# validation loss: 0.5247650146484375
# validation accuracy: 0.8804347826086957
# Save new model!
# --------------------
# * Epoch 2/100
# Loss: 1.27 #nan->0: 100%|██████████| 368/368 [08:45<00:00,  1.43s/it]
# loss: 0.550062
# acc: 0.879076
# start validation
# Loss: 1.78 #nan->0: 100%|██████████| 92/92 [00:48<00:00,  1.90it/s]
# validation loss: 0.4780920743942261
# validation accuracy: 0.8804347826086957
# Save new model!
# --------------------
# * Epoch 3/100
# Loss: 0.19 #nan->0: 100%|██████████| 368/368 [08:43<00:00,  1.42s/it]
# loss: 0.509197
# acc: 0.880435
# start validation
# Loss: 1.66 #nan->0: 100%|██████████| 92/92 [00:48<00:00,  1.90it/s]
# validation loss: 0.4618377983570099
# validation accuracy: 0.8804347826086957
# Save new model!
# --------------------
# * Epoch 4/100
# Loss: 0.12 #nan->0: 100%|██████████| 368/368 [08:45<00:00,  1.43s/it]
# loss: 0.487988
# acc: 0.880435
# start validation
# Loss: 1.62 #nan->0: 100%|██████████| 92/92 [00:48<00:00,  1.90it/s]
# validation loss: 0.42909008264541626
# validation accuracy: 0.8804347826086957
# Save new model!
# --------------------
# * Epoch 5/100
# Loss: 0.31 #nan->0: 100%|██████████| 368/368 [08:43<00:00,  1.42s/it]
# loss: 0.473083
# acc: 0.880435
# start validation
# Loss: 2.03 #nan->0: 100%|██████████| 92/92 [00:48<00:00,  1.89it/s]
# validation loss: 0.48287761211395264
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 6/100
# Loss: 2.99 #nan->0: 100%|██████████| 368/368 [08:41<00:00,  1.42s/it]
# loss: 0.477078
# acc: 0.880435
# start validation
# Loss: 2.11 #nan->0: 100%|██████████| 92/92 [00:48<00:00,  1.90it/s]
# validation loss: 0.47984322905540466
# validation accuracy: 0.8804347826086957
# --------------------
# * Epoch 7/100
# Loss: 0.13 #nan->0: 100%|██████████| 368/368 [08:36<00:00,  1.40s/it]
# loss: 0.472833
# acc: 0.880435
# start validation
# Loss: 2.07 #nan->0: 100%|██████████| 92/92 [00:48<00:00,  1
# Save new model!
# --------------------
# * Epoch 12/100
# Loss: 0.98 #nan->0: 100%|██████████| 689/689 [13:30<00:00,  1.18s/it]
# loss: 0.893117
# acc: 0.653483
# start validation
# Loss: 0.88 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.36it/s]
# validation loss: 0.8583542704582214
# validation accuracy: 0.6635174418604651
# Save new model!
# --------------------
# * Epoch 13/100
# Loss: 0.48 #nan->0: 100%|██████████| 689/689 [13:29<00:00,  1.17s/it]
# loss: 0.871600
# acc: 0.664006
# start validation
# Loss: 0.91 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.35it/s]
# validation loss: 0.8538086414337158
# validation accuracy: 0.6627906976744186
# Save new model!
# --------------------
# * Epoch 14/100
# Loss: 0.75 #nan->0: 100%|██████████| 689/689 [13:28<00:00,  1.17s/it]
# loss: 0.836094
# acc: 0.675980
# start validation
# Loss: 0.80 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.35it/s]
# validation loss: 0.8343921899795532
# validation accuracy: 0.6824127906976745
# Save new model!
# --------------------
# * Epoch 15/100
# Loss: 1.02 #nan->0: 100%|██████████| 689/689 [13:25<00:00,  1.17s/it]
# loss: 0.810226
# acc: 0.689405
# start validation
# Loss: 0.87 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.35it/s]
# validation loss: 0.8605992794036865
# validation accuracy: 0.6649709302325582
# --------------------
# * Epoch 16/100
# Loss: 0.89 #nan->0: 100%|██████████| 689/689 [13:25<00:00,  1.17s/it]
# loss: 0.782427
# acc: 0.698295
# start validation
# Loss: 1.20 #nan->0: 100%|██████████| 172/172 [01:12<00:00,  2.36it/s]
# validation loss: 0.88027423620224
# validation accuracy: 0.65625
# --------------------
# * Epoch 17/100
# Loss: 0.60 #nan->0: 100%|██████████| 689/689 [13:29<00:00,  1.17s/it]
# loss: 0.748914
# acc: 0.713534
# start validation
# Loss: 1.08 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.35it/s]
# validation loss: 0.8454304337501526
# validation accuracy: 0.6635174418604651
# --------------------
# * Epoch 18/100
# Loss: 0.91 #nan->0: 100%|██████████| 689/689 [13:30<00:00,  1.18s/it]
# loss: 0.737199
# acc: 0.720791
# start validation
# Loss: 0.87 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.33it/s]
# validation loss: 0.8443389534950256
# validation accuracy: 0.6693313953488372
# --------------------
# * Epoch 19/100
# Loss: 1.05 #nan->0: 100%|██████████| 689/689 [13:28<00:00,  1.17s/it]
# loss: 0.702198
# acc: 0.729499
# start validation
# Loss: 0.84 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.35it/s]
# validation loss: 0.8250105381011963
# validation accuracy: 0.6962209302325582
# Save new model!
# --------------------
# * Epoch 20/100
# Loss: 0.82 #nan->0: 100%|██████████| 689/689 [13:32<00:00,  1.18s/it]
# loss: 0.669604
# acc: 0.748367
# start validation
# Loss: 0.74 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.35it/s]
# validation loss: 0.8506227731704712
# validation accuracy: 0.6853197674418605
# --------------------
# * Epoch 21/100
# Loss: 1.18 #nan->0: 100%|██████████| 689/689 [13:28<00:00,  1.17s/it]
# loss: 0.661340
# acc: 0.752903
# start validation
# Loss: 0.98 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.35it/s]
# validation loss: 0.8244844675064087
# validation accuracy: 0.6744186046511628
# Save new model!
# --------------------
# * Epoch 22/100
# Loss: 0.66 #nan->0: 100%|██████████| 689/689 [13:27<00:00,  1.17s/it]
# loss: 0.633279
# acc: 0.769231
# start validation
# Loss: 1.24 #nan->0: 100%|██████████| 172/172 [01:13<00:00,  2.34it/s]
# validation loss: 0.9445477724075317
# validation accuracy: 0.6802325581395349
# --------------------
# * Epoch 23/100
# Loss: 0.40 #nan->0:  50%|████▉     | 344/689 [06:45<06:44,  1.17s/it]

# %% [markdown]
# ---------------------------------
# Wav2vec2 con clip di 3 secondi

# %%
from torch.utils.data import TensorDataset, DataLoader

freq=16
duration=3
train_ds = AudiosDataset(train_4['filename'], train_4['label'])
test_ds = AudiosDataset(test_4['filename'], test_4['label'])

batch_size = 8
num_workers = 10
loaders = {
    "train": DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        drop_last=True,
    ),
    "test": DataLoader(
        test_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        drop_last=True,
    ),
}
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
DEVICE = 'cuda'
m = Wav2Vec2Model.from_pretrained("facebook/wav2vec2-base-960h")# torch.hub.load('s3prl/s3prl', 'audio_albert').to(DEVICE)
# Out:
# Some weights of the model checkpoint at facebook/wav2vec2-base-960h were not used when initializing Wav2Vec2Model: ['lm_head.weight', 'lm_head.bias']
# - This IS expected if you are initializing Wav2Vec2Model from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2Model from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2Model were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = Classifier(m)

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 3secondi tanh dropout=0.7 batch=8 wav2vec2
# Out:
# * Epoch 1/100
#   0%|          | 0/689 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 10 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Loss: 1.22 #nan->0: 100%|██████████| 689/689 [08:54<00:00,  1.29it/s]
# loss: 1.236221
# acc: 0.461901
# start validation
# Loss: 1.14 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.43it/s]
# validation loss: 1.1562299728393555
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 2/100
# Loss: 0.85 #nan->0: 100%|██████████| 689/689 [09:00<00:00,  1.28it/s]
# loss: 1.171830
# acc: 0.513062
# start validation
# Loss: 1.15 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.42it/s]
# validation loss: 1.1476317644119263
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 3/100
# Loss: 0.85 #nan->0: 100%|██████████| 689/689 [08:59<00:00,  1.28it/s]
# loss: 1.155986
# acc: 0.523948
# start validation
# Loss: 1.06 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.43it/s]
# validation loss: 1.1247097253799438
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 4/100
# Loss: 0.90 #nan->0: 100%|██████████| 689/689 [08:57<00:00,  1.28it/s]
# loss: 1.136398
# acc: 0.525762
# start validation
# Loss: 1.12 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.43it/s]
# validation loss: 1.122263789176941
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 5/100
# Loss: 1.33 #nan->0: 100%|██████████| 689/689 [09:01<00:00,  1.27it/s]
# loss: 1.123618
# acc: 0.530479
# start validation
# Loss: 1.03 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.41it/s]
# validation loss: 1.0723057985305786
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 6/100
# Loss: 1.03 #nan->0: 100%|██████████| 689/689 [09:00<00:00,  1.28it/s]
# loss: 1.096181
# acc: 0.535196
# start validation
# Loss: 1.02 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.42it/s]
# validation loss: 1.056835412979126
# validation accuracy: 0.5799418604651163
# Save new model!
# --------------------
# * Epoch 7/100
# Loss: 0.77 #nan->0: 100%|██████████| 689/689 [09:00<00:00,  1.27it/s]
# loss: 1.079991
# acc: 0.545174
# start validation
# Loss: 1.02 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.42it/s]
# validation loss: 1
# start validation
# Loss: 1.56 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.40it/s]
# validation loss: 0.8699409365653992
# validation accuracy: 0.6824127906976745
# --------------------
# * Epoch 21/100
# Loss: 0.21 #nan->0: 100%|██████████| 689/689 [08:53<00:00,  1.29it/s]
# loss: 0.645197
# acc: 0.764695
# start validation
# Loss: 0.73 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.38it/s]
# validation loss: 0.8943570852279663
# validation accuracy: 0.6780523255813954
# --------------------
# * Epoch 22/100
# Loss: 0.84 #nan->0: 100%|██████████| 689/689 [08:51<00:00,  1.30it/s]
# loss: 0.635031
# acc: 0.766509
# start validation
# Loss: 1.12 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.40it/s]
# validation loss: 0.8509454727172852
# validation accuracy: 0.6940406976744186
# --------------------
# * Epoch 23/100
# Loss: 0.72 #nan->0: 100%|██████████| 689/689 [08:49<00:00,  1.30it/s]
# loss: 0.598456
# acc: 0.781749
# start validation
# Loss: 1.32 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.41it/s]
# validation loss: 0.8395580649375916
# validation accuracy: 0.6925872093023255
# Save new model!
# --------------------
# * Epoch 24/100
# Loss: 1.70 #nan->0: 100%|██████████| 689/689 [08:49<00:00,  1.30it/s]
# loss: 0.574084
# acc: 0.787373
# start validation
# Loss: 1.12 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.40it/s]
# validation loss: 0.8843223452568054
# validation accuracy: 0.6816860465116279
# --------------------
# * Epoch 25/100
# Loss: 0.68 #nan->0: 100%|██████████| 689/689 [08:52<00:00,  1.29it/s]
# loss: 0.548550
# acc: 0.801705
# start validation
# Loss: 1.36 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.38it/s]
# validation loss: 0.856230616569519
# validation accuracy: 0.6991279069767442
# --------------------
# * Epoch 26/100
# Loss: 0.43 #nan->0: 100%|██████████| 689/689 [08:50<00:00,  1.30it/s]
# loss: 0.528551
# acc: 0.812591
# start validation
# Loss: 1.19 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.38it/s]
# validation loss: 0.9281141757965088
# validation accuracy: 0.6809593023255814
# --------------------
# * Epoch 27/100
# Loss: 0.64 #nan->0: 100%|██████████| 689/689 [08:50<00:00,  1.30it/s]
# loss: 0.508640
# acc: 0.815856
# start validation
# Loss: 1.42 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.39it/s]
# validation loss: 0.8951614499092102
# validation accuracy: 0.7122093023255814
# --------------------
# * Epoch 28/100
# Loss: 0.18 #nan->0: 100%|██████████| 689/689 [08:52<00:00,  1.29it/s]
# loss: 0.486307
# acc: 0.826560
# start validation
# Loss: 1.34 #nan->0: 100%|██████████| 172/172 [00:50<00:00,  3.40it/s]
# validation loss: 0.92388516664505
# validation accuracy: 0.7136627906976745
# --------------------

# %% [markdown]
# #### 4-class classification mockingjay

# %%
from torch.utils.data import TensorDataset, DataLoader

freq=16
duration=5
train_ds = AudiosDataset(train_4['filename'], train_4['label'])
test_ds = AudiosDataset(test_4['filename'], test_4['label'])

batch_size = 8
num_workers = 10
loaders = {
    "train": DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        num_workers=num_workers,
        drop_last=True,
    ),
    "test": DataLoader(
        test_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=num_workers,
        drop_last=True,
    ),
}

# %%
DEVICE = 'cuda'
m = torch.hub.load('s3prl/s3prl', 'mockingjay').to(DEVICE)
# Out:
# Using cache found in /root/.cache/torch/hub/s3prl_s3prl_master
# Using cache found in /root/.cache/torch/hub/s3prl_cache/a2b432be9adba2cb59f5cf89a4cf84d5fff8ec3c9fe248ad53349694565ef8c9
# for https://www.dropbox.com/s/zwsfa6w2iy2cc68/states-500000.ckpt?dl=0
# [UpstreamExpert] - Using the default upstream expert config

# %%
model = Classifier(m)

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi tanh dropout=0.7 batch=8 aalbert
# Out:
# * Epoch 1/100
# Loss: 1.53 #nan->0: 100%|██████████| 689/689 [17:50<00:00,  1.55s/it]
# loss: 1.254204
# acc: 0.458273
# start validation
# Loss: 1.05 #nan->0: 100%|██████████| 172/172 [01:32<00:00,  1.86it/s]
# validation loss: 1.128117561340332
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 2/100
# Loss: 1.01 #nan->0: 100%|██████████| 689/689 [17:01<00:00,  1.48s/it]
# loss: 1.168158
# acc: 0.513244
# start validation
# Loss: 1.04 #nan->0: 100%|██████████| 172/172 [01:32<00:00,  1.86it/s]
# validation loss: 1.0921096801757812
# validation accuracy: 0.559593023255814
# Save new model!
# --------------------
# * Epoch 3/100
# Loss: 1.44 #nan->0: 100%|██████████| 689/689 [16:59<00:00,  1.48s/it]
# loss: 1.118138
# acc: 0.537736
# start validation
# Loss: 1.06 #nan->0: 100%|██████████| 172/172 [01:32<00:00,  1.86it/s]
# validation loss: 1.0590629577636719
# validation accuracy: 0.5741279069767442
# Save new model!
# --------------------
# * Epoch 4/100
# Loss: 1.09 #nan->0: 100%|██████████| 689/689 [16:58<00:00,  1.48s/it]
# loss: 1.078497
# acc: 0.563498
# start validation
# Loss: 1.01 #nan->0: 100%|██████████| 172/172 [01:31<00:00,  1.88it/s]
# validation loss: 1.038193702697754
# validation accuracy: 0.595203488372093
# Save new model!
# --------------------
# * Epoch 5/100
# Loss: 0.51 #nan->0: 100%|██████████| 689/689 [16:52<00:00,  1.47s/it]
# loss: 1.017587
# acc: 0.596517
# start validation
# Loss: 1.03 #nan->0: 100%|██████████| 172/172 [01:31<00:00,  1.87it/s]
# validation loss: 1.0024511814117432
# validation accuracy: 0.596656976744186
# Save new model!
# --------------------
# * Epoch 6/100
# Loss: 0.98 #nan->0:  33%|███▎      | 224/689 [05:34<11:03,  1.43s/it]

# %%
DEVICE = 'cuda'
model.load_state_dict(torch.load('/content/drive/MyDrive/Tesi/Mockingjay/4-class_mockingjay_lr=1e-05_batch=8_16mhz_5sec.bin'))
max_epochs = 100
model = model.to(DEVICE)
lr =1e-5
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr, last_epoch=5)
#16mhz 5secondi tanh dropout=0.7 batch=8 mockingjay
# Out:
# * Epoch 6/100
# Loss: 0.76 #nan->0: 100%|██████████| 689/689 [16:37<00:00,  1.45s/it]
# loss: 0.950930
# acc: 0.630624
# start validation
# Loss: 1.21 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.91it/s]
# validation loss: 1.013177514076233
# validation accuracy: 0.6170058139534884
# Save new model!
# --------------------
# * Epoch 7/100
# Loss: 1.13 #nan->0: 100%|██████████| 689/689 [16:40<00:00,  1.45s/it]
# loss: 0.896593
# acc: 0.652032
# start validation
# Loss: 1.08 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.90it/s]
# validation loss: 0.9612019658088684
# validation accuracy: 0.6162790697674418
# Save new model!
# --------------------
# * Epoch 8/100
# Loss: 0.97 #nan->0: 100%|██████████| 689/689 [16:40<00:00,  1.45s/it]
# loss: 0.868611
# acc: 0.668360
# start validation
# Loss: 1.34 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.90it/s]
# validation loss: 0.9781084060668945
# validation accuracy: 0.6148255813953488
# --------------------
# * Epoch 9/100
# Loss: 0.76 #nan->0: 100%|██████████| 689/689 [16:41<00:00,  1.45s/it]
# loss: 0.828168
# acc: 0.688679
# start validation
# Loss: 1.28 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.91it/s]
# validation loss: 0.9470022320747375
# validation accuracy: 0.6446220930232558
# Save new model!
# --------------------
# * Epoch 10/100
# Loss: 1.10 #nan->0: 100%|██████████| 689/689 [16:39<00:00,  1.45s/it]
# loss: 0.784265
# acc: 0.706821
# start validation
# Loss: 1.36 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.90it/s]
# validation loss: 1.0496550798416138
# validation accuracy: 0.5944767441860465
# --------------------
# * Epoch 11/100
# Loss: 0.84 #nan->0: 100%|██████████| 689/689 [16:37<00:00,  1.45s/it]
# loss: 0.722264
# acc: 0.725871
# start validation
# Loss: 1.14 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.90it/s]
# validation loss: 0.9788231253623962
# validation accuracy: 0.6460755813953488
# --------------------
# * Epoch 12/100
# Loss: 0.50 #nan->0: 100%|██████████| 689/689 [16:35<00:00,  1.44s/it]
# loss: 0.686782
# acc: 0.744739
# start validation
# Loss: 1.40 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.91it/s]
# validation loss: 0.982330858707428
# validation accuracy: 0.6635174418604651
# --------------------
# * Epoch 13/100
# Loss: 0.62 #nan->0: 100%|██████████| 689/689 [16:39<00:00,  1.45s/it]
# loss: 0.654481
# acc: 0.758890
# start validation
# Loss: 1.49 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.90it/s]
# validation loss: 0.9705764651298523
# validation accuracy: 0.6482558139534884
# --------------------
# * Epoch 14/100
# Loss: 0.71 #nan->0: 100%|██████████| 689/689 [16:33<00:00,  1.44s/it]
# loss: 0.603168
# acc: 0.771589
# start validation
# Loss: 1.39 #nan->0: 100%|██████████| 172/172 [01:30<00:00,  1.90it/s]
# validation loss: 0.9696465134620667
# validation accuracy: 0.659156976744186
# --------------------

# %% [markdown]
# ---------------

# %%
DEVICE = 'cuda'
m = torch.hub.load('s3prl/s3prl', 'mockingjay')
# Out:
# Using cache found in /root/.cache/torch/hub/s3prl_s3prl_master
# Using cache found in /root/.cache/torch/hub/s3prl_cache/a2b432be9adba2cb59f5cf89a4cf84d5fff8ec3c9fe248ad53349694565ef8c9
# for https://www.dropbox.com/s/zwsfa6w2iy2cc68/states-500000.ckpt?dl=0
# [UpstreamExpert] - Using the default upstream expert config

# %%
model = Classifier(m)

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =1e-4
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi tanh dropout=0.7 batch=8 aalbert
# Out:
# * Epoch 1/100
# Loss: 1.30 #nan->0: 100%|██████████| 689/689 [16:02<00:00,  1.40s/it]
# loss: 1.235103
# acc: 0.485123
# start validation
# Loss: 1.19 #nan->0: 100%|██████████| 172/172 [01:23<00:00,  2.06it/s]
# validation loss: 1.1668875217437744
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 2/100
# Loss: 1.11 #nan->0: 100%|██████████| 689/689 [15:09<00:00,  1.32s/it]
# loss: 1.228002
# acc: 0.487482
# start validation
# Loss: 1.18 #nan->0: 100%|██████████| 172/172 [01:22<00:00,  2.08it/s]
# validation loss: 1.1738678216934204
# validation accuracy: 0.5174418604651163
# --------------------
# * Epoch 3/100
# Loss: 1.61 #nan->0: 100%|██████████| 689/689 [15:10<00:00,  1.32s/it]
# loss: 1.217934
# acc: 0.490203
# start validation
# Loss: 1.23 #nan->0: 100%|██████████| 172/172 [01:22<00:00,  2.07it/s]
# validation loss: 1.1752747297286987
# validation accuracy: 0.5174418604651163
# --------------------
# * Epoch 4/100
# Loss: 1.27 #nan->0: 100%|██████████| 689/689 [15:10<00:00,  1.32s/it]
# loss: 1.208272
# acc: 0.493832
# start validation
# Loss: 1.15 #nan->0: 100%|██████████| 172/172 [01:22<00:00,  2.07it/s]
# validation loss: 1.1732512712478638
# validation accuracy: 0.5174418604651163
# --------------------
# * Epoch 5/100
# Loss: 1.39 #nan->0: 100%|██████████| 689/689 [15:11<00:00,  1.32s/it]
# loss: 1.203532
# acc: 0.499819
# start validation
# Loss: 1.19 #nan->0: 100%|██████████| 172/172 [01:22<00:00,  2.07it/s]
# validation loss: 1.2109291553497314
# validation accuracy: 0.5174418604651163
# --------------------
# * Epoch 6/100
# Loss: 0.62 #nan->0: 100%|██████████| 689/689 [15:13<00:00,  1.33s/it]
# loss: 1.196313
# acc: 0.502177
# start validation
# Loss: 1.16 #nan->0: 100%|██████████| 172/172 [01:22<00:00,  2.08it/s]
# validation loss: 1.2033722400665283
# validation accuracy: 0.5174418604651163
# --------------------

# %% [markdown]
# -----------------

# %%
DEVICE = 'cuda'
m = torch.hub.load('s3prl/s3prl', 'mockingjay').to(DEVICE)

# %%
model = Classifier(m)

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
lr =8e-6
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"], lr)
#16mhz 5secondi tanh dropout=0.7 batch=8 aalbert
# Out:
# * Epoch 1/100
# Loss: 1.07 #nan->0: 100%|██████████| 689/689 [15:25<00:00,  1.34s/it]
# loss: 1.303631
# acc: 0.446662
# start validation
# Loss: 1.16 #nan->0: 100%|██████████| 172/172 [01:19<00:00,  2.17it/s]
# validation loss: 1.1412473917007446
# validation accuracy: 0.5174418604651163
# Save new model!
# --------------------
# * Epoch 2/100
# Loss: 1.38 #nan->0: 100%|██████████| 689/689 [14:31<00:00,  1.26s/it]
# loss: 1.192866
# acc: 0.501633
# start validation
# Loss: 1.17 #nan->0: 100%|██████████| 172/172 [01:19<00:00,  2.16it/s]
# validation loss: 1.127545714378357
# validation accuracy: 0.5501453488372093
# Save new model!
# --------------------
# * Epoch 3/100
# Loss: 1.73 #nan->0: 100%|██████████| 689/689 [14:31<00:00,  1.27s/it]
# loss: 1.149345
# acc: 0.525399
# start validation
# Loss: 1.11 #nan->0: 100%|██████████| 172/172 [01:19<00:00,  2.16it/s]
# validation loss: 1
# start validation
# Loss: 0.97 #nan->0: 100%|██████████| 172/172 [00:09<00:00, 17.53it/s]
# validation loss: 0.9866144061088562
# validation accuracy: 0.59375
# Save new model!
# --------------------
# * Epoch 6/100
# Loss: 1.18 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.60it/s]
# loss: 0.996082
# acc: 0.587808
# start validation
# Loss: 0.99 #nan->0: 100%|██████████| 172/172 [00:10<00:00, 17.07it/s]
# validation loss: 0.9739264845848083
# validation accuracy: 0.5784883720930233
# Save new model!
# --------------------
# * Epoch 7/100
# Loss: 0.65 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.61it/s]
# loss: 0.962528
# acc: 0.608853
# start validation
# Loss: 0.95 #nan->0: 100%|██████████| 172/172 [00:10<00:00, 17.09it/s]
# validation loss: 0.9552748799324036
# validation accuracy: 0.6082848837209303
# Save new model!
# --------------------
# * Epoch 8/100
# Loss: 1.17 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.69it/s]
# loss: 0.929007
# acc: 0.620827
# start validation
# Loss: 0.94 #nan->0: 100%|██████████| 172/172 [00:10<00:00, 16.99it/s]
# validation loss: 0.9514893889427185
# validation accuracy: 0.5995639534883721
# Save new model!
# --------------------
# * Epoch 9/100
# Loss: 0.40 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.61it/s]
# loss: 0.911833
# acc: 0.629354
# start validation
# Loss: 0.99 #nan->0: 100%|██████████| 172/172 [00:09<00:00, 17.31it/s]
# validation loss: 0.9518867135047913
# validation accuracy: 0.6046511627906976
# --------------------
# * Epoch 10/100
# Loss: 0.40 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.63it/s]
# loss: 0.886314
# acc: 0.643687
# start validation
# Loss: 1.03 #nan->0: 100%|██████████| 172/172 [00:09<00:00, 17.25it/s]
# validation loss: 0.9490363597869873
# validation accuracy: 0.6140988372093024
# Save new model!
# --------------------
# * Epoch 11/100
# Loss: 1.22 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.70it/s]
# loss: 0.865573
# acc: 0.655842
# start validation
# Loss: 0.99 #nan->0: 100%|██████████| 172/172 [00:09<00:00, 17.49it/s]
# validation loss: 0.9442295432090759
# validation accuracy: 0.6148255813953488
# Save new model!
# --------------------
# * Epoch 12/100
# Loss: 0.69 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.68it/s]
# loss: 0.838131
# acc: 0.666546
# start validation
# Loss: 1.06 #nan->0: 100%|██████████| 172/172 [00:10<00:00, 16.99it/s]
# validation loss: 0.9614166617393494
# validation accuracy: 0.5886627906976745
# --------------------
# * Epoch 13/100
# Loss: 1.19 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.55it/s]
# loss: 0.806934
# acc: 0.680515
# start validation
# Loss: 1.10 #nan->0: 100%|██████████| 172/172 [00:10<00:00, 16.98it/s]
# validation loss: 0.9563616514205933
# validation accuracy: 0.6097383720930233
# --------------------
# * Epoch 14/100
# Loss: 0.93 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.64it/s]
# loss: 0.788877
# acc: 0.687409
# start validation
# Loss: 1.21 #nan->0: 100%|██████████| 172/172 [00:10<00:00, 16.95it/s]
# validation loss: 0.9668583273887634
# validation accuracy: 0.6140988372093024
# --------------------
# * Epoch 15/100
# Loss: 1.01 #nan->0: 100%|██████████| 689/689 [00:54<00:00, 12.67it/s]
# loss: 0.752690
# acc: 0.701742
# start validation
# Loss: 1.18 #nan->0: 100%|██████████| 172/172 [00:09<00:00, 17.38it/s]
# validation loss: 0.9823052883148193
# validation accuracy: 0.6082848837209303
# --------------------
# * Epoch 16/100
# Loss: 0.30 #nan->0: 100%|██████████| 689/689 [00:53<00:00, 12.79it/s]
# loss: 0.729697
# acc: 0.715167
# start validation
# Loss: 1.19 #nan->0: 100%|██████████| 172/172 [00:09<00:00, 17.47it/s]
# validation loss: 0.9702529311180115
# validation accuracy: 0.6206395348837209
# --------------------

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"])
#
# Out:
# * Epoch 1/100
# Loss: 1.28 #nan->13: 100%|██████████| 689/689 [47:36<00:00,  4.15s/it]
# loss: 1.364231
# acc: 0.504438
# start validation
# Loss: 1.10 #nan->2: 100%|██████████| 172/172 [12:09<00:00,  4.24s/it]
# validation loss: 1.2355105876922607
# validation accuracy: 0.5154411764705882
# Save new model!
# --------------------
# * Epoch 2/100
# Loss: 0.83 #nan->13: 100%|██████████| 689/689 [48:21<00:00,  4.21s/it]
# loss: 1.318933
# acc: 0.524778
# start validation
# Loss: 1.11 #nan->2: 100%|██████████| 172/172 [11:42<00:00,  4.09s/it]
# validation loss: 1.2214609384536743
# validation accuracy: 0.5161764705882353
# Save new model!
# --------------------
# * Epoch 3/100
# Loss: 0.77 #nan->5:  44%|████▍     | 304/689 [21:12<19:08,  2.98s/it]

# %%
DEVICE = 'cuda'
max_epochs = 100
model = model.to(DEVICE)
torch.cuda.empty_cache()
loss_fn =  nn.CrossEntropyLoss().to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-6)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1, eta_min=1e-8, last_epoch=-1)
train(model, optimizer,scheduler, loss_fn, max_epochs, loaders["train"], loaders["test"])
# Out:
# * Epoch 1/100
# Loss: 1.14 #nan->13: 100%|██████████| 689/689 [37:13<00:00,  3.24s/it]
# loss: 1.571352
# acc: 0.335059
# start validation
# Loss: 1.20 #nan->2: 100%|██████████| 172/172 [08:57<00:00,  3.13s/it]
# validation loss: 1.3547611236572266
# validation accuracy: 0.5154411764705882
# Save new model!
# --------------------
# * Epoch 2/100
# Loss: 1.39 #nan->11:  94%|█████████▍| 650/689 [34:23<02:26,  3.76s/it]

# %%
# ##PRIMO TRAINING
# from tqdm import tqdm
# import math
# from torch import autograd


# def train(model, opt, scheduler, loss_fn, epochs, data_tr, data_val, max_stable=5):
#     best_val_loss = 1e9
#     counter = 0
#     nan=False
#     for epoch in range(epochs):
#         correct_predictions = 0
#         count=0
#         #tic = time()
#         print('* Epoch %d/%d' % (epoch+1, epochs))

#         avg_loss = 0
#         model.train()  # train mode
#         progress = tqdm(data_tr)
#         for batch in progress:
#             loss = 0
#             # data to device
#             X_batch, Y_batch = batch["representation"], batch["target"]
#             # print(X_batch.shape)
#             X_batch = X_batch.to(DEVICE)
#             Y_batch = Y_batch.to(DEVICE)
#             # with torch.autograd.detect_anomaly():
# #                     outputs = GB(inputs)
# #                     loss = LOSS(outputs, labels)
# # #                    loss.register_hook(lambda grad : print(grad))
# #                     loss.backward()
#             # set parameter gradients to zero
#             opt.zero_grad()
#             # forward
#             Y_pred = model(X_batch)
#             # print(X_batch)
#             # print(Y_pred)
#             # print(Y_batch)
#             # Y_pred = torch.tensor([e+1e-6 for e in Y_pred.reshape(1,16)[0].tolist()])
#             # Y_pred = Y_pred.reshape(8,2)
#             _, preds = torch.max(Y_pred, dim=1)
#             # loss = loss_fn(outputs[0], targets)
#             # loss = outputs[0]
#             # print(preds)
#             # print(Y_batch)
#             preds = preds.to(DEVICE)
#             Y_pred = Y_pred.to(DEVICE)
            

#             # print('---------')
#             # print('Y_pred')
#             # print(Y_pred)
            
#             # print('preds')
#             # print(preds)
#             # print('X_batch')
#             # print(X_batch)
#             # print('Y_batch')
#             # print(Y_batch)
#             # print('---------')

#             loss = loss_fn(Y_pred, Y_batch)# forward-pass
#             nan = math.isnan(loss)

#             if nan:
#               count=count+1
#               nan=False
#               continue
#               # print('---------')
#               # print('X_batch')
#               # print(X_batch.isnan().any())
#               # print('Y_pred')
#               # print(Y_pred)
#               # print(Y_pred.isnan().any())
              
#               # print('preds')
#               # print(preds.isnan().any())
              
#               # print('Y_batch')
#               # print(Y_batch.isnan().any())
#               # 
#               # print('---------')
#             # if math.isnan(loss):
#             #   print('ok')
#             # nan = True if loss is np.nan else False
#             # print('-------')
#             # print(loss)
#             # print('-------')
#             correct_predictions += torch.sum(preds == Y_batch)
#             progress.set_description(f'Loss: {loss:.2f} #nan->{count}')
            
#             loss.backward()  # backward-pass
#             # torch.nn.utils.clip_grad_norm_(model.parameters(), 25)
#             opt.step()  # update weights
#             if not scheduler is None:
#                 scheduler.step()
#             # calculate loss to show the user
#             avg_loss += loss / len(data_tr)
#       #  toc = time()
#         avg_acc = correct_predictions.double() / (len(train_ds)-(batch_size*count))
        
#         print('loss: %f' % avg_loss)
#         print('acc: %f' % avg_acc)
#         # show intermediate results
#         model.eval()  # testing mode
#         val_loss = 0
#         print("start validation")
#         for v_b in tqdm(data_val):
#             X_val, Y_val = v_b["representation"], v_b["target"]
#             Y_hat = model(X_val.to(DEVICE)).detach().cpu()# detach and put into cpu
#             val_loss += loss_fn(Y_hat, Y_val)
#         val_loss /= len(data_val)
#         print( f"validation loss: {val_loss}")
#         if val_loss <= best_val_loss and val_loss > 0:
#             counter = 0
#             print("Save new model!")
#             best_val_loss = val_loss
#             torch.save(model.state_dict(), '/content/drive/MyDrive/Tesi/AudioAlbert/wheeze_aalbert.h5')
#         else:
#             counter += 1
#         if counter == max_stable:
#             break
